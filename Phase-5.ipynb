# %%
import pandas  as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data =pd.read_csv("loan_applications_50.csv")
print(data)
# Out:
#     ApplicantID  Gender  Age  Income  LoanAmount Approved
# 0          1001    Male   59   97121      400804       No
# 1          1002    Male   49   99479      234633       No
# 2          1003  Female   35  119475      388998       No
# 3          1004    Male   28   49457      426649       No
# 4          1005    Male   41   96557      204488      Yes
# 5          1006    Male   59  107189      283323       No
# 6          1007    Male   39  108953      384806       No
# 7          1008    Male   43   82995      370536      Yes
# 8          1009  Female   31   70757      130535       No
# 9          1010    Male   31   39692      475713      Yes
# 10         1011    Male   44   75758      414400      Yes
# 11         1012    Male   56  102409      451279      Yes
# 12         1013    Male   44  101211      489622      Yes
# 13         1014    Male   23   95697      397366       No
# 14         1015    Male   42   67065      177373       No
# ...

# %%
data.head(2)
# Out:
#    ApplicantID Gender  Age  Income  LoanAmount Approved
# 0         1001   Male   59   97121      400804       No
# 1         1002   Male   49   99479      234633       No

# %%
data.tail(2)
# Out:
#     ApplicantID Gender  Age  Income  LoanAmount Approved
# 48         1049   Male   37   91858      349002      Yes
# 49         1050   Male   56   42666      350396       No

# %%
data.shape
# Out:
# (50, 6)

# %%
data.info
# Out:
# <bound method DataFrame.info of     ApplicantID  Gender  Age  Income  LoanAmount Approved
# 0          1001    Male   59   97121      400804       No
# 1          1002    Male   49   99479      234633       No
# 2          1003  Female   35  119475      388998       No
# 3          1004    Male   28   49457      426649       No
# 4          1005    Male   41   96557      204488      Yes
# 5          1006    Male   59  107189      283323       No
# 6          1007    Male   39  108953      384806       No
# 7          1008    Male   43   82995      370536      Yes
# 8          1009  Female   31   70757      130535       No
# 9          1010    Male   31   39692      475713      Yes
# 10         1011    Male   44   75758      414400      Yes
# 11         1012    Male   56  102409      451279      Yes
# 12         1013    Male   44  101211      489622      Yes
# 13         1014    Male   23   95697      397366       No
# 14         1015    Male   42   67065      177373       No
# ...

# %%
data.isnull().sum()
# Out:
# ApplicantID    0
# Gender         0
# Age            0
# Income         0
# LoanAmount     0
# Approved       0
# dtype: int64

# %%
data.isnull().sum()/data.shape[0]*100
# Out:
# ApplicantID    0.0
# Gender         0.0
# Age            0.0
# Income         0.0
# LoanAmount     0.0
# Approved       0.0
# dtype: float64

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
data.describe(include="object")
# Out:
#        Gender Approved
# count      50       50
# unique      2        2
# top      Male       No
# freq       32       26

# %%
import seaborn as sea

# %%
for i in data.select_dtypes(include="number"):
    sea.histplot(data=data,x=i)
    plt.xlabel(i)
    plt.grid(True)
    plt.show()

# %%
 for i in data.select_dtypes(include="number"):
        sea.boxenplot(data=data,x=i)
        plt.xlabel(i)
        plt.grid(True)
        plt.show()

# %%
data.select_dtypes(include="number").columns
# Out:
# Index(['ApplicantID', 'Age', 'Income', 'LoanAmount'], dtype='object')

# %%
for i in[ 'Age', 'Income', 'LoanAmount'] :
        sea.scatterplot(data=data,x=i,y='ApplicantID')
        plt.show()

# %%
s=data.select_dtypes(include="number").corr()

# %%
sea.heatmap(s,annot=True)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# ApplicantID    0
# Gender         0
# Age            0
# Income         0
# LoanAmount     0
# Approved       0
# dtype: int64
